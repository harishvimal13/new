# %% [markdown]
# # import libraries

# %%
import pandas as pd
import statistics
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import seaborn as sns

# %% [markdown]
# # Read CSV file

# %%
df=pd.read_csv(r'F:\bike_buyers.csv')
df
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 0    12496        Married  Female   40000.0       1.0        Bachelors
# 1    24107        Married    Male   30000.0       3.0  Partial College
# 2    14177        Married    Male   80000.0       5.0  Partial College
# 3    24381         Single     NaN   70000.0       0.0        Bachelors
# 4    25597         Single    Male   30000.0       0.0        Bachelors
# ..     ...            ...     ...       ...       ...              ...
# 995  23731        Married    Male   60000.0       2.0      High School
# 996  28672         Single    Male   70000.0       4.0  Graduate Degree
# 997  11809        Married     NaN   60000.0       2.0        Bachelors
# 998  19664         Single    Male  100000.0       3.0        Bachelors
# 999  12121         Single    Male   60000.0       3.0      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# ...

# %%
df.head(10)
# Out:
#       ID Marital Status  Gender    Income  Children            Education  \
# 0  12496        Married  Female   40000.0       1.0            Bachelors
# 1  24107        Married    Male   30000.0       3.0      Partial College
# 2  14177        Married    Male   80000.0       5.0      Partial College
# 3  24381         Single     NaN   70000.0       0.0            Bachelors
# 4  25597         Single    Male   30000.0       0.0            Bachelors
# 5  13507        Married  Female   10000.0       2.0      Partial College
# 6  27974         Single    Male  160000.0       2.0          High School
# 7  19364        Married    Male   40000.0       1.0            Bachelors
# 8  22155            NaN    Male   20000.0       2.0  Partial High School
# 9  19280        Married    Male       NaN       2.0      Partial College
#
#        Occupation Home Owner  Cars Commute Distance   Region   Age  \
# 0  Skilled Manual        Yes   0.0        0-1 Miles   Europe  42.0
# ...

# %%
df.tail(10)
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 990  14332         Single  Female   30000.0       0.0      High School
# 991  19117         Single  Female   60000.0       1.0  Graduate Degree
# 992  22864        Married    Male   90000.0       2.0  Partial College
# 993  11292         Single    Male  150000.0       1.0  Partial College
# 994  13466        Married    Male   80000.0       5.0  Partial College
# 995  23731        Married    Male   60000.0       2.0      High School
# 996  28672         Single    Male   70000.0       4.0  Graduate Degree
# 997  11809        Married     NaN   60000.0       2.0        Bachelors
# 998  19664         Single    Male  100000.0       3.0        Bachelors
# 999  12121         Single    Male   60000.0       3.0      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# 990  Skilled Manual         No   2.0       5-10 Miles  North America  26.0
# ...

# %%
df.sample(5)
# Out:
#         ID Marital Status Gender   Income  Children    Education  \
# 525  16791         Single   Male  60000.0       5.0    Bachelors
# 463  19331         Single   Male  20000.0       2.0  High School
# 714  16020        Married   Male  40000.0       0.0  High School
# 736  19634        Married   Male  40000.0       0.0  High School
# 398  27771         Single   Male  30000.0       1.0    Bachelors
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# 525      Management        Yes   3.0        10+ Miles  North America  59.0
# 463          Manual        Yes   1.0        0-1 Miles         Europe  40.0
# 714  Skilled Manual        Yes   2.0       5-10 Miles  North America  28.0
# 736  Skilled Manual        Yes   1.0       5-10 Miles  North America  31.0
# 398        Clerical        Yes   1.0        1-2 Miles         Europe  39.0
#
#     Purchased Bike
# 525            Yes
# 463             No
# 714            Yes
# 736             No
# 398            Yes

# %%
df.shape
# Out:
# (1000, 13)

# %%
df.columns
# Out:
# Index(['ID', 'Marital Status', 'Gender', 'Income', 'Children', 'Education',
#        'Occupation', 'Home Owner', 'Cars', 'Commute Distance', 'Region', 'Age',
#        'Purchased Bike'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning

# %%
df.dtypes
# Out:
# ID                    int64
# Marital Status       object
# Gender               object
# Income              float64
# Children            float64
# Education            object
# Occupation           object
# Home Owner           object
# Cars                float64
# Commute Distance     object
# Region               object
# Age                 float64
# Purchased Bike       object
# dtype: object

# %%
df.isnull().sum()
# Out:
# ID                   0
# Marital Status       7
# Gender              11
# Income               6
# Children             8
# Education            0
# Occupation           0
# Home Owner           4
# Cars                 9
# Commute Distance     0
# Region               0
# Age                  8
# Purchased Bike       0
# dtype: int64

# %%
df1=df.dropna()
df1
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 0    12496        Married  Female   40000.0       1.0        Bachelors
# 1    24107        Married    Male   30000.0       3.0  Partial College
# 2    14177        Married    Male   80000.0       5.0  Partial College
# 4    25597         Single    Male   30000.0       0.0        Bachelors
# 5    13507        Married  Female   10000.0       2.0  Partial College
# ..     ...            ...     ...       ...       ...              ...
# 994  13466        Married    Male   80000.0       5.0  Partial College
# 995  23731        Married    Male   60000.0       2.0      High School
# 996  28672         Single    Male   70000.0       4.0  Graduate Degree
# 998  19664         Single    Male  100000.0       3.0        Bachelors
# 999  12121         Single    Male   60000.0       3.0      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# ...

# %%
df1.describe().T
# Out:
#           count          mean           std      min       25%      50%  \
# ID        952.0  19979.940126   5334.000279  11000.0  15310.25  19747.5
# Income    952.0  55903.361345  30845.483596  10000.0  30000.00  60000.0
# Children  952.0      1.898109      1.620426      0.0      0.00      2.0
# Cars      952.0      1.452731      1.111962      0.0      1.00      1.0
# Age       952.0     44.256303     11.428167     25.0     35.00     43.0
#
#               75%       max
# ID        24531.5   29447.0
# Income    70000.0  170000.0
# Children      3.0       5.0
# Cars          2.0       4.0
# Age          52.0      89.0

# %%
df1.corr()
# Out:
#                 ID    Income  Children      Cars       Age
# ID        1.000000 -0.084555 -0.032756  0.007229 -0.049802
# Income   -0.084555  1.000000  0.260923  0.433365  0.175876
# Children -0.032756  0.260923  1.000000  0.272482  0.536302
# Cars      0.007229  0.433365  0.272482  1.000000  0.193755
# Age      -0.049802  0.175876  0.536302  0.193755  1.000000

# %%
carrh=df1.corr()
plt.figure(figsize=(8,6))
sns.heatmap(carrh, cmap="Greens", annot=True)
# Out:
# <AxesSubplot:>

# %%
df1['Occupation'].unique()
# Out:
# array(['Skilled Manual', 'Clerical', 'Professional', 'Manual',
#        'Management'], dtype=object)

# %%
df1['Education'].unique()
# Out:
# array(['Bachelors', 'Partial College', 'High School',
#        'Partial High School', 'Graduate Degree'], dtype=object)

# %%
df1.sort_values(by=['Age'])
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 164  22402        Married    Male   10000.0       0.0  Partial College
# 165  15465        Married  Female   10000.0       0.0  Partial College
# 195  25559         Single    Male   20000.0       0.0        Bachelors
# 798  22971         Single  Female   30000.0       0.0      High School
# 219  22399         Single    Male   10000.0       0.0  Partial College
# ..     ...            ...     ...       ...       ...              ...
# 553  17533        Married    Male   40000.0       3.0  Partial College
# 250  22931        Married    Male  100000.0       5.0  Graduate Degree
# 595  18058         Single  Female   20000.0       3.0      High School
# 401  11555        Married  Female   40000.0       1.0        Bachelors
# 375  15628        Married  Female   40000.0       1.0        Bachelors
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# ...

# %%
df10=plt.figure(figsize=(25,10))
df10=sns.countplot(x="Age", data=df)

# %% [markdown]
# * in this dataframe contain 25 to 89 age peoples
# * also in this graph we can say  30 to 53 age peoples occupied  maximum

# %% [markdown]
# #converting yes or no into numerical value

# %%
df1['purchase']=df1['Purchased Bike'].apply(lambda x: 1 if str(x)=='Yes' else 0)
# Out:
# <ipython-input-18-0ef4e17be2e2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['purchase']=df1['Purchased Bike'].apply(lambda x: 1 if str(x)=='Yes' else 0)

# %%
df1['purchase']
# Out:
# 0      0
# 1      0
# 2      0
# 4      1
# 5      0
#       ..
# 994    0
# 995    1
# 996    1
# 998    0
# 999    1
# Name: purchase, Length: 952, dtype: int64

# %%
df1
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 0    12496        Married  Female   40000.0       1.0        Bachelors
# 1    24107        Married    Male   30000.0       3.0  Partial College
# 2    14177        Married    Male   80000.0       5.0  Partial College
# 4    25597         Single    Male   30000.0       0.0        Bachelors
# 5    13507        Married  Female   10000.0       2.0  Partial College
# ..     ...            ...     ...       ...       ...              ...
# 994  13466        Married    Male   80000.0       5.0  Partial College
# 995  23731        Married    Male   60000.0       2.0      High School
# 996  28672         Single    Male   70000.0       4.0  Graduate Degree
# 998  19664         Single    Male  100000.0       3.0        Bachelors
# 999  12121         Single    Male   60000.0       3.0      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# ...

# %% [markdown]
# #people owns bikes or not

# %%
df1["Purchased Bike"].value_counts()
# Out:
# No     496
# Yes    456
# Name: Purchased Bike, dtype: int64

# %%
labels = ['No','yes']
colors = ['#8B31AF','#F8B226']
explode = (0.03,0.03)

plt.figure(figsize=(10,8))
plt.pie(df1['purchase'].value_counts(),colors = colors,autopct='%1.1f%%',startangle=90, pctdistance=0.85, explode = explode)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle) 
plt.tight_layout() 
plt.legend(labels)
plt.title("Number Of Bikes  Had And Not ")
plt.show()

# %% [markdown]
# * in this data frame 52.1% people had no bikes
# * only 47.9% people cointain bikes

# %% [markdown]
# #Bike Purchasing Trend According to Numbers of their Children

# %%
sns.histplot(x="Children", data=df, hue="Purchased Bike", multiple="dodge", shrink=0.8, bins=[0, 1, 2, 3, 4, 5, 6], palette=sns.blend_palette(['violet', 'green'], 2))
plt.title('Bike Purchasing Trend According to Numbers of their Children')
plt.show()

# %% [markdown]
# #Bike Purchasing Trend According Occupation

# %%
fig, ax=plt.subplots(figsize=(9, 6))
df1=sns.countplot(x="Purchased Bike", data=df, hue='Occupation', hue_order=['Professional', 'Skilled Manual', 'Clerical', 'Management', 'Manual'])

#Setting labels and font size
df1.set(xlabel='Purchased Bike', ylabel='Count of No/Yes',title="Count of People who Purchased the Bike and who Did't")
df1.xaxis.get_label().set_fontsize(14)
df1.yaxis.get_label().set_fontsize(14)

plt.show()

# %%
sns.histplot(x="Commute Distance", data=df, hue="Purchased Bike", multiple="dodge", shrink=0.8, bins=[0, 1, 2, 3, 4, 5, 6], palette=sns.blend_palette(['gray', 'black'], 2))
plt.title("Bike Purchasing Trend According to Commuting Distance")
plt.show()

# %%
fig, df1=plt.subplots(figsize=(9, 6))
plt.title('Scatter plot Income vs Age')
sns.scatterplot(x="Income", y="Age", data=df, hue="Purchased Bike", palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %%
df2=df1[df1['purchase']==1]
df2
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 4    25597         Single    Male   30000.0       0.0        Bachelors
# 7    19364        Married    Male   40000.0       1.0        Bachelors
# 10   22173        Married  Female   30000.0       3.0      High School
# 13   25323        Married    Male   40000.0       2.0  Partial College
# 14   23542         Single    Male   60000.0       1.0  Partial College
# ..     ...            ...     ...       ...       ...              ...
# 992  22864        Married    Male   90000.0       2.0  Partial College
# 993  11292         Single    Male  150000.0       1.0  Partial College
# 995  23731        Married    Male   60000.0       2.0      High School
# 996  28672         Single    Male   70000.0       4.0  Graduate Degree
# 999  12121         Single    Male   60000.0       3.0      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# ...

# %%
df3=df2.groupby(['Age'],as_index=False)['purchase'].count()
df3
# Out:
#      Age  purchase
# 0   25.0         3
# 1   26.0         8
# 2   27.0         8
# 3   28.0         9
# 4   29.0         5
# 5   30.0         4
# 6   31.0         8
# 7   32.0        14
# 8   33.0        11
# 9   34.0        18
# 10  35.0        21
# 11  36.0        29
# 12  37.0        27
# 13  38.0        27
# 14  39.0        11
# 15  40.0        15
# 16  41.0        13
# 17  42.0        12
# 18  43.0        18
# 19  44.0        12
# 20  45.0        12
# 21  46.0        14
# 22  47.0        19
# 23  48.0        12
# 24  49.0         8
# 25  50.0        12
# 26  51.0        12
# 27  52.0        14
# 28  53.0        13
# 29  54.0        11
# 30  55.0         5
# 31  56.0         3
# 32  57.0         4
# 33  58.0         4
# 34  59.0         6
# 35  60.0         6
# 36  61.0         4
# 37  62.0         4
# 38  63.0         2
# 39  64.0         3
# 40  65.0         3
# 41  66.0         5
# 42  67.0         2
# 43  70.0         1
# 44  72.0         1
# 45  73.0         2
# ...

# %%
plt.figure(figsize=(25,20))
plt.title('Age Cointains Had Bikes')
cht=df2['Age'].value_counts().plot(kind='bar')

# %% [markdown]
# * 36 - 38 age  group people  occupied hold 1st three places
# * above 70 age group people had  least bikes
# * 36 age  group people had 29 bikes

# %% [markdown]
# #Bike Purchasing Trend According to Region

# %%
region_purchase=df2.groupby(['Region'],as_index=False)['purchase'].count()
region_purchase
# Out:
#           Region  purchase
# 0         Europe       139
# 1  North America       211
# 2        Pacific       106

# %%
x=region_purchase['Region']
y=region_purchase['purchase']
plt.title('Region Has More Bikes')
plt.pie(y,labels=x,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# * north america contain 46.3%
# * europe cointain 30.5%
# * pacific cointain 23.2%
# * North America region occupied more bikes.
# * we can sale more bike's in this region..

# %%
df5=df2.groupby(['Home Owner'],as_index=False)['purchase'].count()
df5
# Out:
#   Home Owner  purchase
# 0         No       151
# 1        Yes       305

# %%
x=df5['Home Owner']
y=df5['purchase']
plt.pie(y,labels=x,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# * no=33.1%
# * yes=66.9%
# * by this we can say that people who owns a permanent residence  owns vehicle

# %% [markdown]
# * Bike Purchasing Trend of Home Owners

# %%
df6=df2.groupby(['Home Owner','Cars'],as_index=False)['purchase'].count()
df6
# Out:
#   Home Owner  Cars  purchase
# 0         No   0.0        26
# 1         No   1.0        59
# 2         No   2.0        49
# 3         No   3.0        15
# 4         No   4.0         2
# 5        Yes   0.0       112
# 6        Yes   1.0        89
# 7        Yes   2.0        72
# 8        Yes   3.0        17
# 9        Yes   4.0        15

# %%
df7=df2.groupby(['Home Owner','Education'],as_index=False)['purchase'].count()
df7
# Out:
#   Home Owner            Education  purchase
# 0         No            Bachelors        51
# 1         No      Graduate Degree        16
# 2         No          High School        28
# 3         No      Partial College        51
# 4         No  Partial High School         5
# 5        Yes            Bachelors       108
# 6        Yes      Graduate Degree        74
# 7        Yes          High School        46
# 8        Yes      Partial College        63
# 9        Yes  Partial High School        14

# %%
df7['Home_Owner']=df7['Home Owner'].apply(lambda x: 1 if str(x)=='Yes' else 0)

# %%
df7
# Out:
#   Home Owner            Education  purchase  Home_Owner
# 0         No            Bachelors        51           0
# 1         No      Graduate Degree        16           0
# 2         No          High School        28           0
# 3         No      Partial College        51           0
# 4         No  Partial High School         5           0
# 5        Yes            Bachelors       108           1
# 6        Yes      Graduate Degree        74           1
# 7        Yes          High School        46           1
# 8        Yes      Partial College        63           1
# 9        Yes  Partial High School        14           1

# %%
import seaborn as sns
sns.pairplot(df7)

# %% [markdown]
# #Bike Purchasing Trend According to Education

# %%
df7.plot(x="Education", y=["Home_Owner", "purchase"], kind="bar")
# Out:
# <AxesSubplot:xlabel='Education'>

# %% [markdown]
# * by this way we can say Bachelors  people has more bikes
# * Graduate Degree people has second more bikes

# %%
df8=df7[df7['Home_Owner']==1]
df8
# Out:
#   Home Owner            Education  purchase  Home_Owner
# 5        Yes            Bachelors       108           1
# 6        Yes      Graduate Degree        74           1
# 7        Yes          High School        46           1
# 8        Yes      Partial College        63           1
# 9        Yes  Partial High School        14           1

# %%
x=df8['Education']
y=df8['purchase']
plt.title('Region Has More Bikes')
plt.pie(y,labels=x,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# * Bachelors=35.4%
# * Graduate Degree=24.3%
# * High School=15.1%
# * Partial College=20.7%
# * Partial High School4.6%
# * Bachelors occupied more bikes

# %% [markdown]
# # conclusion

# %% [markdown]
# * no children people owns vehicle
